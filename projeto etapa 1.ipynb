# %% [markdown]
# #.QUESTÂO 1
#  Sim É amplamente possível acessar os arquivos compactados diretamente do site, sem precisar baixá-los .

# %%
# 2018 Agrupados por ocorrência
import numpy as np
import pandas as pd
PRF2k18=pd.read_csv("https://arquivos.prf.gov.br/arquivos/index.php/s/MaC6cieXSFACNWT/download",
                   encoding="latin1",sep=";",low_memory="False",compression="zip")
DFprf18=pd.DataFrame(PRF2k18)
DFprf18
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0       99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1       99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2       99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3       99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4       99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#                        municipio  \
# 0                        RESENDE
# ...

# %%
# 2019 Agrupados por ocorrência
import numpy as np
import pandas as pd
PRF2k19=pd.read_csv("https://arquivos.prf.gov.br/arquivos/index.php/s/kRBUylqz6DyQznN/download",
                   encoding="latin1",sep=";",low_memory="False",compression="zip")
DFprf19=pd.DataFrame(PRF2k19)
DFprf19
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0      182210.0   2019-01-01    terça-feira  01:30:00  SP  116.0    218
# 1      182211.0   2019-01-01    terça-feira  01:30:00  PR  373.0  177,3
# 2      182212.0   2019-01-01    terça-feira  00:45:00  SC  101.0     16
# 3      182214.0   2019-01-01    terça-feira  00:00:00  CE   20.0  429,5
# 4      182215.0   2019-01-01    terça-feira  01:00:00  MG  381.0    327
# ...         ...          ...            ...       ...  ..    ...    ...
# 67441  266255.0   2019-10-07  segunda-feira  09:10:00  ES  101.0  270,5
# 67442  266406.0   2019-11-25  segunda-feira  07:20:00  PR  116.0    125
# 67443  266434.0   2019-06-03  segunda-feira  19:00:00  CE  222.0    1,4
# 67444  266573.0   2019-07-13         sábado  19:35:00  PR  373.0    425
# 67445  266627.0   2019-10-22    terça-feira  20:20:00  BA  324.0    608
#
#                 municipio                       causa_acidente  \
# ...

# %%
# 2020 Agrupados por ocorrência
import numpy as np
import pandas as pd
PRF2k20=pd.read_csv("https://arquivos.prf.gov.br/arquivos/index.php/s/jdDLrQIf33xXSCe/download",
                   encoding="latin1",sep=";",low_memory="False",compression="zip")
DFprf20=pd.DataFrame(PRF2k20)
DFprf20
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 0      260031.0   2020-01-01  quarta-feira  01:00:00  TO  153.0  678,1
# 1      260036.0   2020-01-01  quarta-feira  01:00:00  RJ  116.0    178
# 2      260037.0   2020-01-01  quarta-feira  01:52:00  SC  101.0  206,9
# 3      260038.0   2020-01-01  quarta-feira  01:15:00  RO  364.0    236
# 4      260039.0   2020-01-01  quarta-feira  01:30:00  PR  153.0    360
# ...         ...          ...           ...       ...  ..    ...    ...
# 63543  364615.0   2020-03-20   sexta-feira  09:00:00  RN  304.0  171,8
# 63544  364810.0   2020-09-12        sábado  23:50:00  BA  116.0   11,5
# 63545  364817.0   2020-10-30   sexta-feira  10:30:00  BA  116.0   14,3
# 63546  364835.0   2020-09-20       domingo  23:00:00  BA  116.0      8
# 63547  364903.0   2020-10-31        sábado  02:10:00  BA  116.0      3
#
#                   municipio                causa_acidente  \
# ...

# %% [markdown]
#  QUESTÂO 2
#  OBS:o numero de acidentes é equivalente ao numero de rows do dataframe
#  A) 2018 = 69295| 2019 = 67446 | 2020 = 63548
#  B) todos os conjutos de dados possuem 30 variaveis
#  C) Em 2018 CURITIBA,SAO JOSE,BRASILIA,GUARULHOS,PALHOCA Em 2019 CURITIBA,BRASILIA,SAO JOSE,GUARULHOS,SERRA
#     Em 2020 BRASILIA,CURITIBA,GUARULHOS,SAO JOSE,PALHOCA
# DFprf18['municipio'].value_counts()

# %%
DFprf19['municipio'].value_counts()
# Out:
# CURITIBA               1094
# BRASILIA               1090
# SAO JOSE                819
# GUARULHOS               717
# SERRA                   633
#                        ...
# PALMEIRANTE               1
# ALMINO AFONSO             1
# SANTA CRUZ CABRALIA       1
# PRADO                     1
# AGUA SANTA                1
# Name: municipio, Length: 1767, dtype: int64

# %%
DFprf20['municipio'].value_counts()
# Out:
# BRASILIA                1040
# CURITIBA                 950
# GUARULHOS                639
# SAO JOSE                 629
# PALHOCA                  593
#                         ...
# SAO FERNANDO               1
# VICENTINA                  1
# TACARATU                   1
# FARIAS BRITO               1
# SALVADOR DAS MISSOES       1
# Name: municipio, Length: 1789, dtype: int64

# %%
# D) 
DFprf19['uf'].value_counts()
# Out:
# MG    8720
# SC    8428
# PR    7708
# RJ    4606
# RS    4595
# SP    4377
# BA    3471
# GO    3354
# ES    2842
# PE    2736
# MT    2137
# CE    1694
# PB    1564
# RO    1533
# RN    1437
# MS    1435
# PI    1346
# DF    1090
# MA    1075
# PA     817
# AL     629
# SE     612
# TO     520
# AC     254
# RR     237
# AP     128
# AM     101
# Name: uf, dtype: int64

# %%
# QUESTÂO 3
# A) Ordenar a frequencia de cada uf 
pf121920=pd.concat([DFprf18,DFprf19,DFprf20])
pf121920['uf'].value_counts()
# Out:
# MG    26160
# SC    24145
# PR    22850
# RJ    13417
# RS    13216
# SP    12936
# BA    10482
# GO    10046
# ES     8018
# PE     8011
# MT     6963
# CE     4962
# RO     4648
# PB     4553
# MS     4505
# RN     4190
# PI     3920
# MA     3501
# PA     3040
# DF     2997
# AL     1948
# SE     1746
# TO     1704
# AC      789
# RR      723
# AP      456
# AM      363
# Name: uf, dtype: int64

# %%
# B) Ordenar a frequencia de cada dia
pf121920=pd.concat([DFprf18,DFprf19,DFprf20])
pf121920['dia_semana'].value_counts()
# Out:
# sábado           33005
# domingo          33001
# sexta-feira      30777
# segunda-feira    27075
# quinta-feira     26229
# quarta-feira     25353
# terça-feira      24849
# Name: dia_semana, dtype: int64

# %%
# QUESTÂO 4
# A) mais comum = Falta de Atenção à Condução | mais raras pista esburacada,Acumulo de óleo sobre o pavimento,Estacionar ou parar em local proibido  
# Frear bruscamente entre outras 
pf121920=pd.concat([DFprf18,DFprf19,DFprf20])
pf121920['causa_acidente'].value_counts()
# Out:
# Falta de Atenção à Condução                                                       73231
# Desobediência às normas de trânsito pelo condutor                                 24089
# Velocidade Incompatível                                                           18763
# Ingestão de Álcool                                                                15689
# Não guardar distância de segurança                                                12082
# Defeito Mecânico no Veículo                                                       11190
# Condutor Dormindo                                                                  7225
# Pista Escorregadia                                                                 6752
# Falta de Atenção do Pedestre                                                       5685
# Animais na Pista                                                                   4551
# Ultrapassagem Indevida                                                             3590
# ...

# %%
# B)
# C) ao avaliarmos os dados fica claro que ouvi sim uma diminuição visto que em 2018 teve 69295 acidentes 
#    em 2019 teve 67446 e em 2020 teve 63548 acidentes.
#    de 2018 para 2020 teve uma diminuição de 5747 acidentes.
